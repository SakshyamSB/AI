# %%
import matplotlib.pyplot as plt
import numpy as np
#7 Task 1
Cold = []
Mild = []
Comfortable = []
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1,
17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7,
17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8,
16.6, 12.5]
for i in temperatures:
  if i<10:
    Cold.append(i)
  elif i>10 and i<15:
    Mild.append(i)
  elif i>15 and i <20:
    Comfortable.append(i)
print("Cold: ",Cold,"\nMild: ",Mild,"\nComfortable: ",Comfortable)
#7 Task 2
print("The number of mild temperatures: ",len(Mild))
print("The number of comfortable temperatures: ",len(Comfortable))
print("The number of cold temperatures: ",len(Cold))
#7 Task 3
temperatures_fahrenheit = []
for i in temperatures:
  f = (i*9/5)+32

  temperatures_fahrenheit.append(f)
print("The temperatures in fahrenheit: ",temperatures_fahrenheit)
#7 Task 4
night = []
day = []
evening = []
sum = 0
for j in range(0,8):
  night.append(temperatures[j])
for k in range(8,16):
  evening.append(temperatures[k])
for l in range(16,24):
  day.append(temperatures[l])
for i in day:
  sum = sum + i
avg = sum/len(day)
print("The average of day temps is:",avg)
plt.plot(np.array(temperatures))
plt.plot(np.array(day))
plt.show()
# Out:
# Cold:  [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# Mild:  [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# Comfortable:  [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
# The number of mild temperatures:  16
# The number of comfortable temperatures:  16
# The number of cold temperatures:  16
# The temperatures in fahrenheit:  [46.76, 63.32, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.959999999999994, 55.94, 47.120000000000005, 62.059999999999995, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 55.04, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.519999999999996, 54.86, 48.02, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]
# The average of day temps is: 14.012500000000001

# %%
#8 Task 1
def sum_nested_list(nested_list):
  total = 0
  for element in nested_list:
    if isinstance(element, list): # Check if the element is a list
      total += sum_nested_list(element) # Recursively sum the nested list
    else:
      total += element # Add the number to the total
  return total
sum_nested_list([3, [7, 1, 4,[1,2]],5, [1, 6, 8]])
# Out:
# 38

# %%
#8 Task 2
def generate_permutations(s):
  list1 = []
  if len(s) == 1:
      return [s]


  for i in range(len(s)):
      rem = s[:i] + s[i+1:]
      for p in generate_permutations(rem):
          list1.append(s[i] + p)

  return list(list1)
print(generate_permutations("abc"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
#8 Task 3
def calculate_directory_size(directory):
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:
            total_size += value
    return total_size

directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

print("The total directory size:", calculate_directory_size(directory_structure), "KB")
# Out:
# The total directory size: 1400 KB

# %%
#8.2 Task 1
def min_coins(coins, amount):
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0
    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)
    return dp[amount] if dp[amount] != float('inf') else -1

print("Minimum coins needed:", min_coins([1, 2, 5], 11))
# Out:
# Minimum coins needed: 3

# %%
#8.2 task 2
def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

print("LCS length:", longest_common_subsequence("abcde", "ace"))
# Out:
# LCS length: 3

# %%
#8.2 task 3
def knapsack(weights, values, capacity):

    n = len(weights)
    dp = [0] * (capacity + 1)

    for i in range(n):
        for w in range(capacity, weights[i] - 1, -1):
            dp[w] = max(dp[w], dp[w - weights[i]] + values[i])

    return dp[capacity]

print("Maximum Value:", knapsack([1, 3, 4, 5], [1, 4, 5, 7], 7))
# Out:
# Maximum Value: 9

# %%
from google.colab import drive
drive.mount('/content/drive')
